# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline


car_cascade = cv2.CascadeClassifier('cars.xml')
cap = cv2.VideoCapture('car_mp4.mp4')

while True:
    ret, img = cap.read()
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    cars = car_cascade.detectMultiScale(gray, 1.1, 1)

    for (x,y,w,h) in cars:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,255),2)      

    img = cv2.cvtColor(img, cv2.cv.CV_BGR2RGB)
    plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-7-a88d6cb66df7> in <module>()
#       9 while True:
#      10     ret, img = cap.read()
# ---> 11     gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#      12
#      13     cars = car_cascade.detectMultiScale(gray, 1.1, 1)
#
# error: /tmp/opencv-20160626-36858-1swhgmb/opencv-2.4.13/modules/imgproc/src/color.cpp:3739: error: (-215) scn == 3 || scn == 4 in function cvtColor
